# %% [markdown]
# <a href="https://colab.research.google.com/github/Diane-Divina/DataScience/blob/master/Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
uri="https://raw.githubusercontent.com/Diane-Divina/DataScience/master/README.csv"
pd.read_csv(uri)
# Out:
#            data  temp   pH  turbidez  ...  nitrito  dbo   ppt    od
# 0    30/01/1990  27.0  7.2     42.00  ...    0.090    6   0.0   6.2
# 1    15/03/1990  25.0  7.2     45.00  ...    0.130    3   0.0   5.4
# 2    24/05/1990  17.0  7.0     13.00  ...    0.090    3   0.0   6.0
# 3    11/07/1990  18.0  6.9     17.00  ...    0.130    6   1.0   4.0
# 4    16/10/1990  25.0  6.9     10.00  ...    0.170    6  12.6   2.6
# 5    22/11/1990  27.0  6.9     15.00  ...    0.100   12  16.5   1.4
# 6    18/03/1991  29.0  7.1     53.00  ...    0.004    1   0.0   6.4
# 7    20/05/1991  21.0  6.5     27.00  ...    0.030    2   4.9   7.7
# 8    11/07/1991  18.0  7.1     11.00  ...    0.110    4  14.1   6.2
# 9    09/10/1991  20.0  7.1    175.00  ...    0.090    6   1.9   7.1
# 10   22/01/1992  25.0  6.2     30.00  ...    0.130    5   7.7   3.0
# 11   19/03/1992  27.0  6.7     54.00  ...    0.095    4   7.5   5.0
# 12   14/05/1992  21.0  6.7     22.00  ...    0.120    5   7.8   4.5
# ...
